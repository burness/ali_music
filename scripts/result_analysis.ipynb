# %%
# %pylab inline
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
result_05_16 = pd.read_csv('../data/temp_result.csv')

# %%
result_05_16[['actual_plays','predict_plays']].plot()

# %%
# 看下按天数，50个歌手的播放情况

# %%
artist_ds_plays_pd = pd.read_csv('../data/train_data.csv')

# %%
artist_ds_plays_pd.head(5)
# Out:
#                           artist_id          ds  cnt
# 0  023406156015ef87f99521f3b343f71f  2015-03-01  482
# 1  023406156015ef87f99521f3b343f71f  2015-03-02  449
# 2  023406156015ef87f99521f3b343f71f  2015-03-03  474
# 3  023406156015ef87f99521f3b343f71f  2015-03-04  458
# 4  023406156015ef87f99521f3b343f71f  2015-03-05  398

# %%
artist_ds_plays_pd.groupby('ds')['cnt'].sum().plot()
